# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **MARGARITOPOULOS EMMANOUIL**
# Currently being occupied in the manufacturing industry (elevators) as an industrialisation engineer but i would love to work as a data scientist.

# %% [markdown]
# *I would love to work as a data scientist because i firmly believe that data is the hint given to us people in order to make the world a better place to live.*

# %% [markdown]
# ###My code sample below is going to print my favorite motivation quote

# %%
str= "The future depends on what we do in the present."
print(str)
# Out:
# The future depends on what we do in the present.

# %% [markdown]
# *external link* <a href="https://everydaypower.com/wp-content/uploads/2021/09/Future-quotes-to-help-you-plan-for-it.png"> Link to quote <a>
# ![image.png](attachment:f559e0db-7388-4c3d-aa4f-9710e9222e7c.png)
#     <ol>
#         <li>Football</li>
#         <li>Running</li>
#         <li>Gaming</li>
#     </ol>
# ~~I got struckthrough.~~ I am not!
